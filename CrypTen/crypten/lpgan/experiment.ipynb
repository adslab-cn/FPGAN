# %% [markdown]
# ## Train and Test

# %% [markdown]
# ## TABLE VII + Table V
# 在三个不同的网络结构下的效果

# %%
#!/usr/bin/env python3

# Copyright (c) Facebook, Inc. and its affiliates.
#
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.

import tempfile

import crypten
import crypten.communicator as comm
import torch
import torch.nn as nn
import torch.nn.functional as F
from examples.util import NoopContextManager
from torchvision import datasets, transforms
import crypten.mpc as mpc
from crypten.lpgan.Secfunctions import track_network_traffic, get_network_bytes, calculate_network_traffic, timeit, print_execution_times, print_communication_costs

@mpc.run_multiprocess(world_size=2)
def run_mpc_autograd_cnn(
    context_manager=None,
    num_epochs=1,
    learning_rate=0.001,
    batch_size=128,
    print_freq=5,
    num_samples=60000,
):
    """
    Args:
        context_manager: used for setting proxy settings during download.
    """
    crypten.init()

    data_alice, data_bob, train_labels, test_data_alice, test_data_bob, test_labels = preprocess_mnist(context_manager)
    rank = comm.get().get_rank()

    # assumes at least two parties exist
    # broadcast dummy data with same shape to remaining parties
    if rank == 0:
        x_alice = data_alice
    else:
        x_alice = torch.empty(data_alice.size())

    if rank == 1:
        x_bob = data_bob
    else:
        x_bob = torch.empty(data_bob.size())

    # encrypt
    x_alice_enc = crypten.cryptensor(x_alice, src=0)
    x_bob_enc = crypten.cryptensor(x_bob, src=1)

    # combine feature sets
    x_combined_enc = crypten.cat([x_alice_enc, x_bob_enc], dim=2)
    x_combined_enc = x_combined_enc.unsqueeze(1)

    # reduce training set to num_samples
    x_reduced = x_combined_enc[:num_samples]
    y_reduced = train_labels[:num_samples]

    # encrypt plaintext model
    model_plaintext = CNN()
    dummy_input = torch.empty((1, 1, 28, 28))
    model = crypten.nn.from_pytorch(model_plaintext, dummy_input)
    model.train()
    model.encrypt()

    # encrypted training
    train_encrypted(
        x_reduced, y_reduced, model, num_epochs, learning_rate, batch_size, print_freq
    )
    
########################################################################
#===============================Test====================================
########################################################################
    # Testing on MNIST test set

    if rank == 0:
        x_test_alice = test_data_alice
    else:
        x_test_alice = torch.empty(test_data_alice.size())

    if rank == 1:
        x_test_bob = test_data_bob
    else:
        x_test_bob = torch.empty(test_data_bob.size())

    # encrypt test data
    x_test_alice_enc = crypten.cryptensor(x_test_alice, src=0)
    x_test_bob_enc = crypten.cryptensor(x_test_bob, src=1)

    x_test_combined_enc = crypten.cat([x_test_alice_enc, x_test_bob_enc], dim=2).unsqueeze(1)
    x_test = x_test_combined_enc[:10000]
    y_test = test_labels[:10000]

    model.eval()
    # run test
    test_encrypted(x_test, y_test, model, batch_size, print_freq)
    print_execution_times() # offline 的时间成本
    
@timeit
def train_encrypted(
    x_encrypted,
    y_encrypted,
    encrypted_model,
    num_epochs,
    learning_rate,
    batch_size,
    print_freq,
):
    rank = comm.get().get_rank()
    loss = crypten.nn.CrossEntropyLoss()

    num_samples = x_encrypted.size(0)
    # label_eye = torch.eye(2)
    label_eye = torch.eye(10)


    for epoch in range(num_epochs):
        last_progress_logged = 0
        # only print from rank 0 to avoid duplicates for readability
        if rank == 0:
            print(f"Epoch {epoch} in progress:")

        for j in range(0, num_samples, batch_size):

            # define the start and end of the training mini-batch
            start, end = j, min(j + batch_size, num_samples)

            # switch on autograd for training examples
            x_train = x_encrypted[start:end]
            x_train.requires_grad = True
            y_one_hot = label_eye[y_encrypted[start:end]]
            y_train = crypten.cryptensor(y_one_hot, requires_grad=True)

            # perform forward pass:
            output = encrypted_model(x_train)
            loss_value = loss(output, y_train)

            # backprop
            encrypted_model.zero_grad()
            loss_value.backward() # CrypTen implements encrypted SGD by implementing its own `backward` function
            encrypted_model.update_parameters(learning_rate)

            # log progress
            if j + batch_size - last_progress_logged >= print_freq:
                last_progress_logged += print_freq
                print(f"Loss {loss_value.get_plain_text().item():.4f}")

        # compute accuracy every epoch
        pred = output.get_plain_text().argmax(1)
        correct = pred.eq(y_encrypted[start:end])
        correct_count = correct.sum(0, keepdim=True).float()
        accuracy = correct_count.mul_(100.0 / output.size(0))

        loss_plaintext = loss_value.get_plain_text().item()
        print(
            f"Epoch {epoch} completed: "
            f"Loss {loss_plaintext:.4f} Accuracy {accuracy.item():.2f}"
        )
@timeit
@track_network_traffic
def test_encrypted(
    x_encrypted,
    y_encrypted,
    encrypted_model,
    batch_size,
    print_freq,
):
    rank = comm.get().get_rank()
    loss = crypten.nn.CrossEntropyLoss()
    

    num_samples = x_encrypted.size(0)
    label_eye = torch.eye(10)

    total_loss = 0.0
    total_correct = 0
    total_samples = 0

    for j in range(0, num_samples, batch_size):
        # define the start and end of the testing mini-batch
        start, end = j, min(j + batch_size, num_samples)

        # switch on autograd for testing examples
        x_test = x_encrypted[start:end]
        x_test.requires_grad = True
        y_one_hot = label_eye[y_encrypted[start:end]]
        y_test = crypten.cryptensor(y_one_hot, requires_grad=True)

        # perform forward pass:
        output = encrypted_model(x_test)
        loss_value = loss(output, y_test)

        # accumulate loss
        total_loss += loss_value.get_plain_text().item() * (end - start)

        # compute accuracy
        pred = output.get_plain_text().argmax(1)
        correct = pred.eq(y_encrypted[start:end])
        correct_count = correct.sum(0, keepdim=True).float()
        total_correct += correct_count.item()
        total_samples += (end - start)

        # log progress
        if (j + batch_size) % print_freq == 0:
            print(f"Processed {end}/{num_samples} samples. Loss: {loss_value.get_plain_text().item():.4f}")

    # compute average loss and accuracy
    avg_loss = total_loss / total_samples
    accuracy = total_correct / total_samples * 100.0

    if rank == 0:
        print(f"Test completed: Loss {avg_loss:.4f} Accuracy {accuracy:.2f}%")


def preprocess_mnist(context_manager):
    if context_manager is None:
        context_manager = NoopContextManager()

    # with context_manager:
    #     # each party gets a unique temp directory
    #     with tempfile.TemporaryDirectory() as data_dir:
    #         mnist_train = datasets.MNIST(data_dir, download=True, train=True)
    #         mnist_test = datasets.MNIST(data_dir, download=True, train=False)
    mnist_train = datasets.MNIST('../data', download=True, train=True)
    mnist_test = datasets.MNIST('../data', download=True, train=False)

    # modify labels so all non-zero digits have class label 1
    mnist_train.targets[mnist_train.targets != 0] = 1
    mnist_test.targets[mnist_test.targets != 0] = 1
    mnist_train.targets[mnist_train.targets == 0] = 0
    mnist_test.targets[mnist_test.targets == 0] = 0

    # compute normalization factors
    data_all = torch.cat([mnist_train.data, mnist_test.data]).float()
    data_mean, data_std = data_all.mean(), data_all.std()
    tensor_mean, tensor_std = data_mean.unsqueeze(0), data_std.unsqueeze(0)

    # normalize data
    data_train_norm = transforms.functional.normalize(
        mnist_train.data.float(), tensor_mean, tensor_std
    )
    data_test_norm = transforms.functional.normalize(
        mnist_test.data.float(), tensor_mean, tensor_std
    )

    # partition features between Alice and Bob
    data_alice = data_train_norm[:, :, :20]
    data_bob = data_train_norm[:, :, 20:]
    train_labels = mnist_train.targets

    test_data_alice = data_test_norm[:, :, :20]
    test_data_bob = data_test_norm[:, :, 20:]
    test_labels = mnist_test.targets

    return data_alice, data_bob, train_labels, test_data_alice, test_data_bob, test_labels

# 加载测试集
def load_test_data():
    mnist_test = datasets.MNIST('../data', download=True, train=True)

    # 正常化测试数据
    data_all = torch.cat([mnist_test.data]).float()
    data_mean, data_std = data_all.mean(), data_all.std()
    tensor_mean, tensor_std = data_mean.unsqueeze(0), data_std.unsqueeze(0)

    # 对测试数据进行标准化
    data_test_norm = transforms.functional.normalize(
        mnist_test.data.float(), tensor_mean, tensor_std
    )
    
    test_labels = mnist_test.targets
    return data_test_norm, test_labels

# class CNN(nn.Module):
#     """
#     C: 1conv, 2FC with ReLU
#     """
#     def __init__(self):
#         super(CNN, self).__init__()
#         self.conv1 = nn.Conv2d(1, 16, kernel_size=5, padding=0)
#         self.fc1 = nn.Linear(16 * 24 * 24, 100)  # 调整输入维度
#         self.fc2 = nn.Linear(100, 10)

#     def forward(self, x):
#         out = self.conv1(x)
#         out = F.relu(out)
#         out = out.view(-1, 9216)
#         out = self.fc1(out)
#         out = F.relu(out)
#         out = self.fc2(out)
#         return out
     
class CNN(nn.Module):
    """
    B: 1-Conv, 2-FC with square activation
    """
    def __init__(self):
        super(CNN, self).__init__()
        # 1个卷积层，输入通道1，输出通道16，卷积核大小为5，零填充0
        self.conv1 = nn.Conv2d(1, 16, kernel_size=5, padding=0)  
        
        # 两个全连接层，连接16个特征通道的 24x24 输出和128维度，然后64维度
        self.fc1 = nn.Linear(16 * 24 * 24, 128)
        self.fc2 = nn.Linear(128, 10)  # 输出维度调整为10类

    def square_activation(self, x):
        return x ** 2  # 方形激活函数

    def forward(self, x):
        # Conv 层
        print("before conv1 x'size:", x.size())  # 打印输入尺寸
        
        x = self.conv1(x)  # 经过卷积层
        print("after conv1 x'size:", x.size())  # 打印卷积后的尺寸
        
        x = self.square_activation(x)  # 应用方形激活函数
        x = x.view(-1, 16 * 24 * 24)  # 展平维度，变为(batch_size, 16*24*24)
        
        print("after view x'size:", x.size())  # 打印展平后的尺寸
        
        # 全连接层
        out = self.fc1(x)
        out = self.square_activation(out)  # 应用方形激活函数
        out = self.fc2(out)
        
        return out
    

# class CNN(nn.Module):
#     """
#     A: 3FC with square activation
#     """
#     def __init__(self):
#         super(CNN, self).__init__()
#         self.fc1 = nn.Linear(784, 128)
#         self.fc2 = nn.Linear(128, 64)
#         # self.fc3 = nn.Linear(64, 2)
#         self.fc3 = nn.Linear(64, 10)

#     def square_activation(self, x):
#         return x ** 2  # Square activation function

#     def forward(self, x):
#         print("before view x'size:", x.size())
#         x = x.view(-1, 784)
#         print("after view x'size:", x.size())
#         out = self.fc1(x)
#         out = self.square_activation(out)  # Apply square activation
#         out = self.fc2(out)
#         out = self.square_activation(out)  # Apply square activation
#         out = self.fc3(out)
#         return out
    
if __name__ == "__main__":
    run_mpc_autograd_cnn()
# Out:
# /home/sue/Project/PR-crypten/CrypTen/crypten/__init__.py:64: RuntimeWarning: CrypTen is already initialized.
#   warnings.warn("CrypTen is already initialized.", RuntimeWarning)
# /home/sue/Project/PR-crypten/CrypTen/crypten/__init__.py:64: RuntimeWarning: CrypTen is already initialized.
#   warnings.warn("CrypTen is already initialized.", RuntimeWarning)
# before conv1 x'size:
# /home/sue/anaconda3/envs/crypten/lib/python3.7/site-packages/ipykernel_launcher.py:317: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# before conv1 x'size: torch.Size([1, 1, 28, 28])
# /home/sue/anaconda3/envs/crypten/lib/python3.7/site-packages/ipykernel_launcher.py:317: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# torch.Size([1, 1, 28, 28])
# after conv1 x'size:
# /home/sue/anaconda3/envs/crypten/lib/python3.7/site-packages/ipykernel_launcher.py:320: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# torch.Size([1, 16, 24, 24])after conv1 x'size:
# /home/sue/anaconda3/envs/crypten/lib/python3.7/site-packages/ipykernel_launcher.py:320: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# after view x'size:torch.Size([1, 16, 24, 24])
# /home/sue/anaconda3/envs/crypten/lib/python3.7/site-packages/ipykernel_launcher.py:325: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# torch.Size([1, 9216])
# after view x'size:
# /home/sue/anaconda3/envs/crypten/lib/python3.7/site-packages/ipykernel_launcher.py:325: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# torch.Size([1, 9216])
# before conv1 x'size:before conv1 x'size: torch.Size([1, 1, 28, 28])
#  torch.Size([1, 1, 28, 28])after conv1 x'size:
#  torch.Size([1, 16, 24, 24])
# after conv1 x'size:after view x'size:  torch.Size([1, 16, 24, 24])torch.Size([1, 9216])
#
# after view x'size: torch.Size([1, 9216])
# /home/sue/Project/PR-crypten/CrypTen/crypten/nn/onnx_converter.py:177: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   param = torch.from_numpy(numpy_helper.to_array(node))
# /home/sue/Project/PR-crypten/CrypTen/crypten/nn/onnx_converter.py:177: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   param = torch.from_numpy(numpy_helper.to_array(node))
# Epoch 0 in progress:
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 3.1206Loss 3.1206
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 2.2599Loss 2.2599
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.6512Loss 1.6512
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.5220Loss 1.5220
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.3365Loss 1.3365
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 1.0632Loss 1.0632
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.9594Loss 0.9594
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.0477Loss 1.0477
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.0459Loss 1.0459
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.8479
# Loss 0.8479
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 0.8432Loss 0.8432
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.0012Loss 1.0012
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.8843Loss 0.8843
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7998Loss 0.7998
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.8090Loss 0.8090
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7007Loss 0.7007
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7008Loss 0.7008
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7629Loss 0.7629
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 0.7492Loss 0.7492
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7002Loss 0.7002
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6888Loss 0.6888
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7371Loss 0.7371
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7378Loss 0.7378
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7052Loss 0.7052
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6932Loss 0.6932
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7005Loss 0.7005
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7248Loss 0.7248
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6983Loss 0.6983
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7134Loss 0.7134
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7109Loss 0.7109
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6812Loss 0.6812
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6620Loss 0.6620
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7753Loss 0.7753
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7336Loss 0.7336
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6795Loss 0.6795
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6997Loss 0.6997
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6655Loss 0.6655
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7008Loss 0.7008
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6770Loss 0.6770
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7196Loss 0.7196
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7288Loss 0.7288
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7151Loss 0.7151
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6752Loss 0.6752
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6596Loss 0.6596
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6630Loss 0.6630
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6907Loss 0.6907
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6788Loss 0.6788
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6640Loss 0.6640
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6292Loss 0.6292
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6946Loss 0.6946
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6764Loss 0.6764
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6406Loss 0.6406
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7076Loss 0.7076
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7086Loss 0.7086
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6828Loss 0.6828
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6534Loss 0.6534
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7736Loss 0.7736
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7529Loss 0.7529
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6662Loss 0.6662
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7257Loss 0.7257
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6457Loss 0.6457
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6715Loss 0.6715
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6902Loss 0.6902
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.8146Loss 0.8146
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6931Loss 0.6931
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6853Loss 0.6853
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7951Loss 0.7951
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.6177Loss 1.6177
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.0780Loss 1.0780
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 1.2922Loss 1.2922
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.8102Loss 0.8102
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6970Loss 0.6970
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.8052Loss 0.8052
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7422Loss 0.7422
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6810Loss 0.6810
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7254Loss 0.7254
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6570Loss 0.6570
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# Loss 0.7131Loss 0.7131
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6613Loss 0.6613
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7052Loss 0.7052
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.8036Loss 0.8036
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 1.8172Loss 1.8172
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7840Loss 0.7840
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7497Loss 0.7497
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6969Loss 0.6969
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7292Loss 0.7292
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6838Loss 0.6838
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6927Loss 0.6927
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7705Loss 0.7705
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6937Loss 0.6937
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6905Loss 0.6905
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7141Loss 0.7141
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6671Loss 0.6671
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7167Loss 0.7167
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6972Loss 0.6972
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6517Loss 0.6517
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6752Loss 0.6752
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6591Loss 0.6591
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6759Loss 0.6759
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7268Loss 0.7268
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6760Loss 0.6760
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6840Loss 0.6840
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7674
# Loss 0.7674
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6727Loss 0.6727
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6610Loss 0.6610
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6506Loss 0.6506
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6640Loss 0.6640
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7071Loss 0.7071
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6719Loss 0.6719
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6805Loss 0.6805
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6407Loss 0.6407
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7110Loss 0.7110
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6532Loss 0.6532
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6627Loss 0.6627
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6764Loss 0.6764
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7089Loss 0.7089
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6578Loss 0.6578
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6432Loss 0.6432
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6601Loss 0.6601
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6395Loss 0.6395
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6879Loss 0.6879
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6771Loss 0.6771
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6394Loss 0.6394
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6834Loss 0.6834
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6559Loss 0.6559
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7168Loss 0.7168
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6713Loss 0.6713
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6488Loss 0.6488
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6263Loss 0.6263
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6308Loss 0.6308
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6306Loss 0.6306
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6895Loss 0.6895
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7567Loss 0.7567
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6540Loss 0.6540
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6963Loss 0.6963
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6676Loss 0.6676
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7147Loss 0.7147
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7296Loss 0.7296
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
#
# output's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# Loss 0.7088Loss 0.7088
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6966Loss 0.6966
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6604Loss 0.6604
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6498Loss 0.6498
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6806Loss 0.6806
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6736Loss 0.6736
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6549Loss 0.6549
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6583Loss 0.6583
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6599Loss 0.6599
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6923Loss 0.6923
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6520Loss 0.6520
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6680Loss 0.6680
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6439Loss 0.6439
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6348Loss 0.6348
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# ...
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6347Loss 0.6347
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6210Loss 0.6210
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6107Loss 0.6107
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6298Loss 0.6298
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6137Loss 0.6137
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6124Loss 0.6124
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6355Loss 0.6355
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6334Loss 0.6334
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6156Loss 0.6156
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6097Loss 0.6097
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6191Loss 0.6191
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6225Loss 0.6225
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6450Loss 0.6450
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6109Loss 0.6109
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6205Loss 0.6205
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6223Loss 0.6223
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6147Loss 0.6147
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6667Loss 0.6667
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6397Loss 0.6397
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6561Loss 0.6561
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6395Loss 0.6395
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
#
# y_train's size:torch.Size([128, 10])
# Loss 0.6389Loss 0.6389
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6261Loss 0.6261
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6616Loss 0.6616
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6548Loss 0.6548
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6367Loss 0.6367
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6429Loss 0.6429
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6321Loss 0.6321
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6768Loss 0.6768
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6328Loss 0.6328
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6277Loss 0.6277
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6310Loss 0.6310
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6433Loss 0.6433
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6233Loss 0.6233
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6598Loss 0.6598
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6533Loss 0.6533
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6342Loss 0.6342
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6301Loss 0.6301
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6130Loss 0.6130
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6063Loss 0.6063
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6099Loss 0.6099
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6131Loss 0.6131
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6067Loss 0.6067
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.7047Loss 0.7047
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6234Loss 0.6234
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6712Loss 0.6712
#
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
# x_train shape after view: torch.Size([128, 1, 28, 28])
#
#
#
# output's size:torch.Size([128, 10])
# output's size:torch.Size([128, 10])
#
#
# y_train's size:torch.Size([128, 10])
# y_train's size:torch.Size([128, 10])
#
# Loss 0.6160Loss 0.6160
#
#
# x_train shape after view: torch.Size([96, 1, 28, 28])
#
# x_train shape after view: torch.Size([96, 1, 28, 28])
#
#
#
# output's size:torch.Size([96, 10])
# output's size:torch.Size([96, 10])
#
#
# y_train's size:torch.Size([96, 10])
#
# y_train's size:torch.Size([96, 10])
# Loss 0.6817Loss 0.6817
#
# Epoch 0 completed: Loss 0.6817 Accuracy 96.88Epoch 0 completed: Loss 0.6817 Accuracy 96.88
#
# Processed 640/10000 samples. Loss: 0.6301Processed 640/10000 samples. Loss: 0.6301
#
# Processed 1280/10000 samples. Loss: 0.6345Processed 1280/10000 samples. Loss: 0.6345
#
# Processed 1920/10000 samples. Loss: 0.6308Processed 1920/10000 samples. Loss: 0.6308
#
# Processed 2560/10000 samples. Loss: 0.7076Processed 2560/10000 samples. Loss: 0.7076
#
# Processed 3200/10000 samples. Loss: 0.6353Processed 3200/10000 samples. Loss: 0.6353
#
# Processed 3840/10000 samples. Loss: 0.6334Processed 3840/10000 samples. Loss: 0.6334
#
# Processed 4480/10000 samples. Loss: 0.6712Processed 4480/10000 samples. Loss: 0.6712
#
# Processed 5120/10000 samples. Loss: 0.6057Processed 5120/10000 samples. Loss: 0.6057
#
# Processed 5760/10000 samples. Loss: 0.6142Processed 5760/10000 samples. Loss: 0.6142
#
# Processed 6400/10000 samples. Loss: 0.6063Processed 6400/10000 samples. Loss: 0.6063
#
# Processed 7040/10000 samples. Loss: 0.6068Processed 7040/10000 samples. Loss: 0.6068
#
# Processed 7680/10000 samples. Loss: 0.6095Processed 7680/10000 samples. Loss: 0.6095
#
# Processed 8320/10000 samples. Loss: 0.6127Processed 8320/10000 samples. Loss: 0.6127
#
# Processed 8960/10000 samples. Loss: 0.6060Processed 8960/10000 samples. Loss: 0.6060
#
# Processed 9600/10000 samples. Loss: 0.6056Processed 9600/10000 samples. Loss: 0.6056
#
#
# Execution Time Summary:Test completed: Loss 0.6306 Accuracy 99.34%
#
# Total time for generate_random_ring_element: 704.9623 seconds
# Execution Time Summary:
#
# Total time for generate_additive_triple: 485.6984 secondsTotal time for generate_random_ring_element: 707.6282 seconds
#
# Total time for generate_kbit_random_tensor: 441.4184 secondsTotal time for generate_additive_triple: 498.6786 seconds
#
# Total time for generate_kbit_random_tensor: 440.5493 secondsTotal time for generate_binary_triple: 520.8612 seconds
#
# Total time for generate_binary_triple: 550.3377 secondsTotal time for B2A_rng: 37.6411 seconds
#
# Total time for B2A_rng: 40.3613 secondsTotal time for square: 41.2123 seconds
#
# Total time for square: 43.2153 secondsTotal time for train_encrypted: 2523.1939 seconds
#
# Total time for train_encrypted: 2523.1936 secondsTotal time for test_encrypted: 56.7414 seconds
#
# Total time for test_encrypted: 56.7431 seconds
# Total execution time: 4811.7291 seconds
#
#
# Total execution time: 4860.7072 seconds

# %% [markdown]
# ## Table VI
# SECURE TRAINING
#
# NETWORK: A, BATCHSIZE: 128, EPOCH: 15

# %%
#!/usr/bin/env python3

# Copyright (c) Facebook, Inc. and its affiliates.
#
# This source code is licensed under the MIT license found in the
# LICENSE file in the root directory of this source tree.

import tempfile

import crypten
import crypten.communicator as comm
import torch
import torch.nn as nn
import torch.nn.functional as F
from examples.util import NoopContextManager
from torchvision import datasets, transforms
import crypten.mpc as mpc
from crypten.lpgan.Secfunctions import SecAnd, SecOr, get_network_bytes, calculate_network_traffic, timeit, print_execution_times, print_communication_costs

@mpc.run_multiprocess(world_size=2)
@timeit
def run_mpc_autograd_cnn(
    context_manager=None,
    num_epochs=2,
    learning_rate=0.001,
    batch_size=128,
    print_freq=5,
    num_samples=60000,
):
    """
    Args:
        context_manager: used for setting proxy settings during download.
    """
    crypten.init()

    data_alice, data_bob, train_labels = preprocess_mnist(context_manager)
    rank = comm.get().get_rank()

    # assumes at least two parties exist
    # broadcast dummy data with same shape to remaining parties
    if rank == 0:
        x_alice = data_alice
    else:
        x_alice = torch.empty(data_alice.size())

    if rank == 1:
        x_bob = data_bob
    else:
        x_bob = torch.empty(data_bob.size())

    # encrypt
    x_alice_enc = crypten.cryptensor(x_alice, src=0)
    x_bob_enc = crypten.cryptensor(x_bob, src=1)

    # combine feature sets
    x_combined_enc = crypten.cat([x_alice_enc, x_bob_enc], dim=2)
    x_combined_enc = x_combined_enc.unsqueeze(1)

    # reduce training set to num_samples
    x_reduced = x_combined_enc[:num_samples]
    y_reduced = train_labels[:num_samples]

    # encrypt plaintext model
    model_plaintext = CNN()
    dummy_input = torch.empty((1, 1, 28, 28))
    model = crypten.nn.from_pytorch(model_plaintext, dummy_input)
    model.train()
    model.encrypt()

    # encrypted training
    train_encrypted(
        x_reduced, y_reduced, model, num_epochs, learning_rate, batch_size, print_freq
    )
    print_execution_times() # offline 的时间成本

def train_encrypted(
    x_encrypted,
    y_encrypted,
    encrypted_model,
    num_epochs,
    learning_rate,
    batch_size,
    print_freq,
):
    rank = comm.get().get_rank()
    loss = crypten.nn.CrossEntropyLoss()

    num_samples = x_encrypted.size(0)
    # label_eye = torch.eye(2)
    label_eye = torch.eye(10)


    for epoch in range(num_epochs):
        last_progress_logged = 0
        # only print from rank 0 to avoid duplicates for readability
        if rank == 0:
            print(f"Epoch {epoch} in progress:")

        for j in range(0, num_samples, batch_size):

            # define the start and end of the training mini-batch
            start, end = j, min(j + batch_size, num_samples)

            # switch on autograd for training examples
            x_train = x_encrypted[start:end]
            x_train.requires_grad = True
            y_one_hot = label_eye[y_encrypted[start:end]]
            y_train = crypten.cryptensor(y_one_hot, requires_grad=True)

            # perform forward pass:
            output = encrypted_model(x_train)

            loss_value = loss(output, y_train)

            # backprop
            encrypted_model.zero_grad()
            loss_value.backward()
            encrypted_model.update_parameters(learning_rate)

            # log progress
            if j + batch_size - last_progress_logged >= print_freq:
                last_progress_logged += print_freq
                print(f"Loss {loss_value.get_plain_text().item():.4f}")

        # compute accuracy every epoch
        pred = output.get_plain_text().argmax(1)
        correct = pred.eq(y_encrypted[start:end])
        correct_count = correct.sum(0, keepdim=True).float()
        accuracy = correct_count.mul_(100.0 / output.size(0))

        loss_plaintext = loss_value.get_plain_text().item()
        print(
            f"Epoch {epoch} completed: "
            f"Loss {loss_plaintext:.4f} Accuracy {accuracy.item():.2f}"
        )


def preprocess_mnist(context_manager):
    if context_manager is None:
        context_manager = NoopContextManager()

    mnist_train = datasets.MNIST('../data', download=True, train=True)
    mnist_test = datasets.MNIST('../data', download=True, train=False)

    # modify labels so all non-zero digits have class label 1
    mnist_train.targets[mnist_train.targets != 0] = 1
    mnist_test.targets[mnist_test.targets != 0] = 1
    mnist_train.targets[mnist_train.targets == 0] = 0
    mnist_test.targets[mnist_test.targets == 0] = 0

    # compute normalization factors
    data_all = torch.cat([mnist_train.data, mnist_test.data]).float()
    data_mean, data_std = data_all.mean(), data_all.std()
    tensor_mean, tensor_std = data_mean.unsqueeze(0), data_std.unsqueeze(0)

    # normalize data
    data_train_norm = transforms.functional.normalize(
        mnist_train.data.float(), tensor_mean, tensor_std
    )
    data_test_norm = transforms.functional.normalize(
        mnist_test.data.float(), tensor_mean, tensor_std
    )

    # partition features between Alice and Bob
    data_alice = data_train_norm[:, :, :20]
    data_bob = data_train_norm[:, :, 20:]
    train_labels = mnist_train.targets

    test_data_alice = data_test_norm[:, :, :20]
    test_data_bob = data_test_norm[:, :, 20:]
    test_labels = mnist_test.targets

    return data_alice, data_bob, train_labels

# 加载测试集
def load_test_data():
    mnist_test = datasets.MNIST('../data', download=True, train=True)

    # 正常化测试数据
    data_all = torch.cat([mnist_test.data]).float()
    data_mean, data_std = data_all.mean(), data_all.std()
    tensor_mean, tensor_std = data_mean.unsqueeze(0), data_std.unsqueeze(0)

    # 对测试数据进行标准化
    data_test_norm = transforms.functional.normalize(
        mnist_test.data.float(), tensor_mean, tensor_std
    )
    
    test_labels = mnist_test.targets
    return data_test_norm, test_labels

class CNN(nn.Module):
    """
    A: 3FC with square activation
    """
    def __init__(self):
        super(CNN, self).__init__()
        self.fc1 = nn.Linear(784, 128)
        self.fc2 = nn.Linear(128, 64)
        # self.fc3 = nn.Linear(64, 2)
        self.fc3 = nn.Linear(64, 10)

    def square_activation(self, x):
        return x ** 2  # Square activation function

    def forward(self, x):
        x = x.view(-1, 784)
        out = self.fc1(x)
        out = self.square_activation(out)  # Apply square activation
        out = self.fc2(out)
        out = F.softmax(out)  # Apply square activation
        out = self.fc3(out)
        return out
    
if __name__ == "__main__":
    run_mpc_autograd_cnn()
# Out:
# /home/sue/Project/PR-crypten/CrypTen/crypten/__init__.py:64: RuntimeWarning: CrypTen is already initialized.
#   warnings.warn("CrypTen is already initialized.", RuntimeWarning)
# /home/sue/Project/PR-crypten/CrypTen/crypten/__init__.py:64: RuntimeWarning: CrypTen is already initialized.
#   warnings.warn("CrypTen is already initialized.", RuntimeWarning)
# /tmp/ipykernel_31770/3380810180.py:211: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.softmax(out)  # Apply square activation
# /tmp/ipykernel_31770/3380810180.py:211: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   out = F.softmax(out)  # Apply square activation
# /home/sue/Project/PR-crypten/CrypTen/crypten/nn/onnx_converter.py:177: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   param = torch.from_numpy(numpy_helper.to_array(node))
# /home/sue/Project/PR-crypten/CrypTen/crypten/nn/onnx_converter.py:177: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:199.)
#   param = torch.from_numpy(numpy_helper.to_array(node))
# Epoch 0 in progress:
# Loss 2.6927Loss 2.6927
#
# Loss 2.6995Loss 2.6995
#
# Loss 2.7002Loss 2.7002
#
# Loss 2.6963Loss 2.6963
#
# Loss 2.6960Loss 2.6960
#
# Loss 2.6950Loss 2.6950
#
# Loss 2.6961Loss 2.6961
#
# Loss 2.6945Loss 2.6945
#
# Loss 2.6955Loss 2.6955
#
# Loss 2.7007Loss 2.7007
#
# Loss 2.6927Loss 2.6927
#
# Loss 2.6934Loss 2.6934
#
# Loss 2.6960Loss 2.6960
#
# Loss 2.6929Loss 2.6929
#
# Loss 2.6905Loss 2.6905
#
# Loss 2.6941Loss 2.6941
#
# Loss 2.6900Loss 2.6900
#
# Loss 2.6929Loss 2.6929
#
# Loss 2.6919Loss 2.6919
#
# Loss 2.6865Loss 2.6865
#
# Loss 2.6906Loss 2.6906
#
# Loss 2.6896Loss 2.6896
#
# Loss 2.6877Loss 2.6877
#
# Loss 2.6880Loss 2.6880
#
# Loss 2.6906Loss 2.6906
#
# Loss 2.6901Loss 2.6901
#
# Loss 2.6870Loss 2.6870
#
# Loss 2.6879Loss 2.6879
#
# Loss 2.6848Loss 2.6848
#
# Loss 2.6861Loss 2.6861
#
# Loss 2.6853Loss 2.6853
#
# Loss 2.6877Loss 2.6877
#
# Loss 2.6835Loss 2.6835
#
# Loss 2.6806Loss 2.6806
#
# Loss 2.6874Loss 2.6874
#
# Loss 2.6794Loss 2.6794
#
# Loss 2.6797Loss 2.6797
#
# Loss 2.6829Loss 2.6829
#
# Loss 2.6824Loss 2.6824
#
# Loss 2.6790Loss 2.6790
#
# Loss 2.6790Loss 2.6790
#
# Loss 2.6757Loss 2.6757
#
# Loss 2.6815Loss 2.6815
#
# Loss 2.6783Loss 2.6783
#
# Loss 2.6790Loss 2.6790
#
# Loss 2.6802Loss 2.6802
#
# Loss 2.6784Loss 2.6784
#
# Loss 2.6792Loss 2.6792
#
# Loss 2.6814Loss 2.6814
#
# Loss 2.6749Loss 2.6749
#
# Loss 2.6759Loss 2.6759
#
# Loss 2.6753Loss 2.6753
#
# Loss 2.6754Loss 2.6754
#
# Loss 2.6809Loss 2.6809
#
# Loss 2.6694Loss 2.6694
#
# Loss 2.6771Loss 2.6771
#
# Loss 2.6764Loss 2.6764
#
# Loss 2.6749Loss 2.6749
#
# Loss 2.6761Loss 2.6761
#
# Loss 2.6748Loss 2.6748
#
# Loss 2.6740Loss 2.6740
#
# Loss 2.6703Loss 2.6703
#
# Loss 2.6715Loss 2.6715
#
# Loss 2.6705Loss 2.6705
#
# Loss 2.6691Loss 2.6691
#
# Loss 2.6731Loss 2.6731
#
# Loss 2.6718Loss 2.6718
#
# Loss 2.6759Loss 2.6759
#
# Loss 2.6732Loss 2.6732
#
# Loss 2.6681Loss 2.6681
#
# Loss 2.6653Loss 2.6653
#
# Loss 2.6708Loss 2.6708
#
# Loss 2.6702Loss 2.6702
#
# Loss 2.6685Loss 2.6685
#
# Loss 2.6689Loss 2.6689
#
# Loss 2.6656Loss 2.6656
#
# Loss 2.6678Loss 2.6678
#
# Loss 2.6638Loss 2.6638
#
# Loss 2.6633Loss 2.6633
#
# Loss 2.6659Loss 2.6659
#
# Loss 2.6598Loss 2.6598
#
# Loss 2.6662Loss 2.6662
#
# Loss 2.6649Loss 2.6649
#
# Loss 2.6674Loss 2.6674
#
# Loss 2.6641Loss 2.6641
#
# Loss 2.6669Loss 2.6669
#
# Loss 2.6599Loss 2.6599
#
# Loss 2.6647Loss 2.6647
#
# Loss 2.6598Loss 2.6598
#
# Loss 2.6612Loss 2.6612
#
# Loss 2.6592Loss 2.6592
#
# Loss 2.6621Loss 2.6621
#
# Loss 2.6576Loss 2.6576
#
# Loss 2.6600Loss 2.6600
#
# Loss 2.6595Loss 2.6595
#
# Loss 2.6607Loss 2.6607
#
# Loss 2.6580Loss 2.6580
#
# Loss 2.6613Loss 2.6613
#
# Loss 2.6574Loss 2.6574
#
# Loss 2.6567Loss 2.6567
#
# Loss 2.6587Loss 2.6587
#
# Loss 2.6603Loss 2.6603
#
# Loss 2.6581Loss 2.6581
#
# Loss 2.6532Loss 2.6532
#
# Loss 2.6583Loss 2.6583
#
# Loss 2.6557Loss 2.6557
#
# Loss 2.6599Loss 2.6599
#
# Loss 2.6524Loss 2.6524
#
# Loss 2.6524Loss 2.6524
#
# Loss 2.6540Loss 2.6540
#
# Loss 2.6486Loss 2.6486
#
# Loss 2.6496Loss 2.6496
#
# Loss 2.6563Loss 2.6563
#
# Loss 2.6534Loss 2.6534
#
# Loss 2.6530Loss 2.6530
#
# Loss 2.6525Loss 2.6525
#
# Loss 2.6510Loss 2.6510
#
# Loss 2.6497Loss 2.6497
#
# Loss 2.6494Loss 2.6494
#
# Loss 2.6500Loss 2.6500
#
# Loss 2.6504Loss 2.6504
#
# Loss 2.6447Loss 2.6447
#
# Loss 2.6476Loss 2.6476
#
# Loss 2.6450Loss 2.6450
#
# Loss 2.6466Loss 2.6466
#
# Loss 2.6497Loss 2.6497
#
# Loss 2.6471Loss 2.6471
#
# Loss 2.6480Loss 2.6480
#
# Loss 2.6460Loss 2.6460
#
# Loss 2.6445Loss 2.6445
#
# Loss 2.6472Loss 2.6472
#
# Loss 2.6470Loss 2.6470
#
# Loss 2.6450Loss 2.6450
#
# Loss 2.6436Loss 2.6436
#
# Loss 2.6449Loss 2.6449
#
# Loss 2.6426Loss 2.6426
#
# Loss 2.6387Loss 2.6387
#
# Loss 2.6433Loss 2.6433
#
# Loss 2.6423Loss 2.6423
#
# Loss 2.6431Loss 2.6431
#
# Loss 2.6413Loss 2.6413
#
# Loss 2.6394Loss 2.6394
#
# Loss 2.6374Loss 2.6374
#
# Loss 2.6415Loss 2.6415
#
# Loss 2.6388Loss 2.6388
#
# Loss 2.6372Loss 2.6372
#
# Loss 2.6388Loss 2.6388
#
# Loss 2.6349Loss 2.6349
#
# Loss 2.6355Loss 2.6355
#
# Loss 2.6366Loss 2.6366
#
# Loss 2.6384Loss 2.6384
#
# Loss 2.6373Loss 2.6373
#
# Loss 2.6318Loss 2.6318
#
# Loss 2.6326Loss 2.6326
#
# Loss 2.6320Loss 2.6320
#
# Loss 2.6379Loss 2.6379
#
# Loss 2.6333Loss 2.6333
#
# Loss 2.6334Loss 2.6334
#
# Loss 2.6355Loss 2.6355
#
# Loss 2.6353Loss 2.6353
#
# Loss 2.6322Loss 2.6322
#
# Loss 2.6297Loss 2.6297
#
# Loss 2.6306Loss 2.6306
#
# Loss 2.6276Loss 2.6276
#
# Loss 2.6318Loss 2.6318
#
# Loss 2.6329Loss 2.6329
#
# Loss 2.6269Loss 2.6269
#
# Loss 2.6322Loss 2.6322
#
# Loss 2.6279Loss 2.6279
#
# Loss 2.6300Loss 2.6300
#
# Loss 2.6311Loss 2.6311
#
# Loss 2.6268Loss 2.6268
#
# Loss 2.6318Loss 2.6318
#
# Loss 2.6268Loss 2.6268
#
# Loss 2.6262Loss 2.6262
#
# Loss 2.6263Loss 2.6263
#
# Loss 2.6265Loss 2.6265
#
# Loss 2.6234Loss 2.6234
#
# Loss 2.6255Loss 2.6255
#
# Loss 2.6247Loss 2.6247
#
# Loss 2.6242Loss 2.6242
#
# Loss 2.6259Loss 2.6259
#
# Loss 2.6215Loss 2.6215
#
# Loss 2.6245Loss 2.6245
#
# Loss 2.6236Loss 2.6236
#
# Loss 2.6212Loss 2.6212
#
# Loss 2.6220Loss 2.6220
#
# Loss 2.6236Loss 2.6236
#
# Loss 2.6194Loss 2.6194
#
# Loss 2.6195Loss 2.6195
#
# Loss 2.6179Loss 2.6179
#
# Loss 2.6206Loss 2.6206
#
# Loss 2.6183Loss 2.6183
#
# Loss 2.6193Loss 2.6193
#
# Loss 2.6203Loss 2.6203
#
# Loss 2.6176Loss 2.6176
#
# Loss 2.6162Loss 2.6162
#
# Loss 2.6163Loss 2.6163
#
# Loss 2.6161Loss 2.6161
#
# Loss 2.6183Loss 2.6183
#
# Loss 2.6164Loss 2.6164
#
# Loss 2.6159Loss 2.6159
#
# Loss 2.6144Loss 2.6144
#
# Loss 2.6128Loss 2.6128
#
# Loss 2.6147Loss 2.6147
#
# Loss 2.6132Loss 2.6132
#
# Loss 2.6130Loss 2.6130
#
# Loss 2.6116Loss 2.6116
#
# Loss 2.6118Loss 2.6118
#
# Loss 2.6135Loss 2.6135
#
# Loss 2.6104Loss 2.6104
#
# Loss 2.6124Loss 2.6124
#
# Loss 2.6111Loss 2.6111
#
# Loss 2.6096Loss 2.6096
#
# Loss 2.6080Loss 2.6080
#
# Loss 2.6070Loss 2.6070
#
# Loss 2.6098Loss 2.6098
#
# Loss 2.6092Loss 2.6092
#
# Loss 2.6069Loss 2.6069
#
# Loss 2.6082Loss 2.6082
#
# Loss 2.6091Loss 2.6091
#
# Loss 2.6044Loss 2.6044
#
# Loss 2.6054Loss 2.6054
#
# Loss 2.6066Loss 2.6066
#
# Loss 2.6052Loss 2.6052
#
# Loss 2.6045Loss 2.6045
#
# Loss 2.6052Loss 2.6052
#
# Loss 2.6038Loss 2.6038
#
# Loss 2.6048Loss 2.6048
#
# Loss 2.6013Loss 2.6013
#
# Loss 2.6009Loss 2.6009
#
# Loss 2.6032Loss 2.6032
#
# Loss 2.6003Loss 2.6003
#
# Loss 2.6010Loss 2.6010
#
# Loss 2.6019Loss 2.6019
#
# Loss 2.6003Loss 2.6003
#
# Loss 2.6000Loss 2.6000
#
# Loss 2.6001Loss 2.6001
#
# Loss 2.6037Loss 2.6037
#
# Loss 2.5969Loss 2.5969
#
# Loss 2.5995Loss 2.5995
#
# Loss 2.5983Loss 2.5983
#
# Loss 2.6013Loss 2.6013
#
# Loss 2.5947Loss 2.5947
#
# Loss 2.6007Loss 2.6007
#
# Loss 2.5988Loss 2.5988
#
# Loss 2.5953Loss 2.5953
#
# Loss 2.5946Loss 2.5946
#
# Loss 2.5944Loss 2.5944
#
# Loss 2.5930Loss 2.5930
#
# Loss 2.5948Loss 2.5948
#
# Loss 2.5928Loss 2.5928
#
# Loss 2.5941Loss 2.5941
#
# Loss 2.5929Loss 2.5929
#
# Loss 2.5913Loss 2.5913
#
# Loss 2.5901Loss 2.5901
#
# Loss 2.5905Loss 2.5905
#
# Loss 2.5924Loss 2.5924
#
# Loss 2.5914Loss 2.5914
#
# Loss 2.5898Loss 2.5898
#
# Loss 2.5907Loss 2.5907
#
# Loss 2.5893Loss 2.5893
#
# Loss 2.5894Loss 2.5894
#
# Loss 2.5873Loss 2.5873
#
# Loss 2.5871Loss 2.5871
#
# Loss 2.5875Loss 2.5875
#
# Loss 2.5879Loss 2.5879
#
# Loss 2.5881Loss 2.5881
#
# Loss 2.5859Loss 2.5859
#
# Loss 2.5862Loss 2.5862
#
# Loss 2.5851Loss 2.5851
#
# Loss 2.5860Loss 2.5860
#
# Loss 2.5839Loss 2.5839
#
# Loss 2.5838Loss 2.5838
#
# Loss 2.5833Loss 2.5833
#
# Loss 2.5832Loss 2.5832
#
# Loss 2.5836Loss 2.5836
#
# Loss 2.5829Loss 2.5829
#
# Loss 2.5828Loss 2.5828
#
# Loss 2.5825Loss 2.5825
#
# Loss 2.5812Loss 2.5812
#
# Loss 2.5825Loss 2.5825
#
# Loss 2.5801Loss 2.5801
#
# Loss 2.5795Loss 2.5795
#
# Loss 2.5797Loss 2.5797
#
# Loss 2.5789Loss 2.5789
#
# Loss 2.5780Loss 2.5780
#
# Loss 2.5781Loss 2.5781
#
# Loss 2.5770Loss 2.5770
#
# Loss 2.5779Loss 2.5779
#
# Loss 2.5770Loss 2.5770
#
# Loss 2.5746Loss 2.5746
#
# Loss 2.5759Loss 2.5759
#
# Loss 2.5739Loss 2.5739
#
# Loss 2.5759Loss 2.5759
#
# Loss 2.5747Loss 2.5747
#
# Loss 2.5739Loss 2.5739
#
# Loss 2.5754Loss 2.5754
#
# Loss 2.5736Loss 2.5736
#
# Loss 2.5737Loss 2.5737
#
# Loss 2.5727Loss 2.5727
#
# Loss 2.5719Loss 2.5719
#
# Loss 2.5731Loss 2.5731
#
# Loss 2.5703Loss 2.5703
#
# Loss 2.5712Loss 2.5712
#
# Loss 2.5700Loss 2.5700
#
# Loss 2.5703Loss 2.5703
#
# Loss 2.5687Loss 2.5687
#
# Loss 2.5683Loss 2.5683
#
# Loss 2.5681Loss 2.5681
#
# Loss 2.5698Loss 2.5698
#
# Loss 2.5681Loss 2.5681
#
# Loss 2.5678Loss 2.5678
#
# Loss 2.5686Loss 2.5686
#
# Loss 2.5679Loss 2.5679
#
# Loss 2.5662Loss 2.5662
#
# Loss 2.5655Loss 2.5655
#
# Loss 2.5631Loss 2.5631
#
# Loss 2.5653Loss 2.5653
#
# Loss 2.5645Loss 2.5645
#
# Loss 2.5641Loss 2.5641
#
# Loss 2.5643Loss 2.5643
#
# Loss 2.5638Loss 2.5638
#
# Loss 2.5649Loss 2.5649
#
# Loss 2.5619Loss 2.5619
#
# Loss 2.5639Loss 2.5639
#
# Loss 2.5613Loss 2.5613
#
# Loss 2.5606Loss 2.5606
#
# Loss 2.5609Loss 2.5609
#
# Loss 2.5607Loss 2.5607
#
# Loss 2.5594Loss 2.5594
#
# Loss 2.5586Loss 2.5586
#
# Loss 2.5562Loss 2.5562
#
# Loss 2.5570Loss 2.5570
#
# Loss 2.5584Loss 2.5584
#
# Loss 2.5577Loss 2.5577
#
# Loss 2.5576Loss 2.5576
#
# Loss 2.5567Loss 2.5567
#
# Loss 2.5556Loss 2.5556
#
# Loss 2.5547Loss 2.5547
#
# Loss 2.5552Loss 2.5552
#
# Loss 2.5538Loss 2.5538
#
# Loss 2.5518Loss 2.5518
#
# Loss 2.5542Loss 2.5542
#
# Loss 2.5524Loss 2.5524
#
# Loss 2.5521Loss 2.5521
#
# Loss 2.5524Loss 2.5524
#
# Loss 2.5499Loss 2.5499
#
# Loss 2.5512Loss 2.5512
#
# Loss 2.5518Loss 2.5518
#
# Loss 2.5523Loss 2.5523
#
# Loss 2.5477Loss 2.5477
#
# Loss 2.5501Loss 2.5501
#
# Loss 2.5492Loss 2.5492
#
# Loss 2.5497Loss 2.5497
#
# Loss 2.5488Loss 2.5488
#
# Loss 2.5462Loss 2.5462
#
# Loss 2.5474Loss 2.5474
#
# Loss 2.5469Loss 2.5469
#
# Loss 2.5476Loss 2.5476
#
# Loss 2.5447Loss 2.5447
#
# Loss 2.5442Loss 2.5442
#
# Loss 2.5454Loss 2.5454
#
# Loss 2.5443Loss 2.5443
#
# Loss 2.5439Loss 2.5439
#
# Loss 2.5450Loss 2.5450
#
# Loss 2.5452Loss 2.5452
#
# Loss 2.5441Loss 2.5441
#
# Loss 2.5434Loss 2.5434
#
# Loss 2.5430Loss 2.5430
#
# Loss 2.5440Loss 2.5440
#
# Loss 2.5390Loss 2.5390
#
# Loss 2.5419Loss 2.5419
#
# Loss 2.5406Loss 2.5406
#
# Loss 2.5379Loss 2.5379
#
# Loss 2.5365Loss 2.5365
#
# Loss 2.5403Loss 2.5403
#
# Loss 2.5375Loss 2.5375
#
# Loss 2.5372Loss 2.5372
#
# Loss 2.5396Loss 2.5396
#
# Loss 2.5375Loss 2.5375
#
# Loss 2.5341Loss 2.5341
#
# Loss 2.5355Loss 2.5355
#
# Loss 2.5359Loss 2.5359
#
# Loss 2.5381Loss 2.5381
#
# Loss 2.5364Loss 2.5364
#
# Loss 2.5352Loss 2.5352
#
# Loss 2.5337Loss 2.5337
#
# Loss 2.5334Loss 2.5334
#
# Loss 2.5328Loss 2.5328
#
# Loss 2.5361Loss 2.5361
#
# Loss 2.5314Loss 2.5314
#
# Loss 2.5316Loss 2.5316
#
# Loss 2.5316Loss 2.5316
#
# Loss 2.5336Loss 2.5336
#
# Loss 2.5307Loss 2.5307
#
# Loss 2.5296Loss 2.5296
#
# Loss 2.5282Loss 2.5282
#
# Loss 2.5331Loss 2.5331
#
# Loss 2.5263Loss 2.5263
#
# Loss 2.5302Loss 2.5302
#
# Loss 2.5270Loss 2.5270
#
# Loss 2.5265Loss 2.5265
#
# Loss 2.5261Loss 2.5261
#
# Loss 2.5297Loss 2.5297
#
# Loss 2.5242Loss 2.5242
#
# Loss 2.5284Loss 2.5284
#
# Loss 2.5261Loss 2.5261
#
# Loss 2.5270Loss 2.5270
#
# Loss 2.5232Loss 2.5232
#
# Loss 2.5216Loss 2.5216
#
# Loss 2.5262Loss 2.5262
#
# Loss 2.5246Loss 2.5246
#
# Loss 2.5205Loss 2.5205
#
# Loss 2.5237Loss 2.5237
#
# Loss 2.5193Loss 2.5193
#
# Loss 2.5252Loss 2.5252
#
# Loss 2.5250Loss 2.5250
#
# Loss 2.5190Loss 2.5190
#
# Loss 2.5176Loss 2.5176
#
# Loss 2.5181Loss 2.5181
#
# Loss 2.5233Loss 2.5233
#
# Loss 2.5164Loss 2.5164
#
# Loss 2.5135Loss 2.5135
#
# Loss 2.5189Loss 2.5189
#
# Loss 2.5185Loss 2.5185
#
# Loss 2.5143Loss 2.5143
#
# Loss 2.5135Loss 2.5135
#
# Loss 2.5176Loss 2.5176
#
# Loss 2.5182Loss 2.5182
#
# Loss 2.5132Loss 2.5132
#
# Loss 2.5152Loss 2.5152
#
# Loss 2.5151Loss 2.5151
#
# Loss 2.5110Loss 2.5110
#
# Loss 2.5148Loss 2.5148
#
# Loss 2.5113Loss 2.5113
#
# Loss 2.5124Loss 2.5124
#
# Loss 2.5078Loss 2.5078
#
# Loss 2.5123Loss 2.5123
#
# Loss 2.5068Loss 2.5068
#
# Loss 2.5139Loss 2.5139
#
# Loss 2.5109Loss 2.5109
#
# Loss 2.5082Loss 2.5082
#
# Loss 2.5097Loss 2.5097
#
# Loss 2.5079Loss 2.5079
#
# Loss 2.5098Loss 2.5098
#
# Loss 2.5078Loss 2.5078
#
# Loss 2.5036Loss 2.5036
#
# Loss 2.5089Loss 2.5089
#
# Loss 2.5061Loss 2.5061
#
# Loss 2.5099Loss 2.5099
#
# Loss 2.5067Loss 2.5067
#
# Loss 2.5043Loss 2.5043
#
# Loss 2.5067Loss 2.5067
#
# Loss 2.5018Loss 2.5018
#
# Loss 2.5053Loss 2.5053
#
# Loss 2.5037Loss 2.5037
#
# Loss 2.5034Loss 2.5034
#
# Loss 2.5012Loss 2.5012
#
# Loss 2.5040Loss 2.5040
#
# Loss 2.4974Loss 2.4974
#
# Loss 2.5003Loss 2.5003
#
# Loss 2.5019Loss 2.5019
#
# Loss 2.4992Loss 2.4992
#
# Loss 2.4984Loss 2.4984
#
# Loss 2.4975Loss 2.4975
#
# Loss 2.4982Loss 2.4982
#
# Loss 2.4970Loss 2.4970
#
# Loss 2.4973Loss 2.4973
#
# Epoch 0 completed: Loss 2.4973 Accuracy 90.62Epoch 0 completed: Loss 2.4973 Accuracy 90.62
#
# Epoch 1 in progress:
# Loss 2.5018Loss 2.5018
#
# Loss 2.4966Loss 2.4966
#
# Loss 2.4920Loss 2.4920
#
# Loss 2.4962Loss 2.4962
#
# Loss 2.4948Loss 2.4948
#
# Loss 2.4954Loss 2.4954
#
# Loss 2.4939Loss 2.4939
#
# Loss 2.4940Loss 2.4940
#
# Loss 2.4948Loss 2.4948
#
# Loss 2.4863Loss 2.4863
#
# Loss 2.4926Loss 2.4926
#
# Loss 2.4923Loss 2.4923
#
# Loss 2.4897Loss 2.4897
#
# Loss 2.4914Loss 2.4914
#
# Loss 2.4920Loss 2.4920
#
# Loss 2.4864Loss 2.4864
#
# Loss 2.4907Loss 2.4907
#
# Loss 2.4862Loss 2.4862
#
# Loss 2.4888Loss 2.4888
#
# Loss 2.4904Loss 2.4904
#
# Loss 2.4885Loss 2.4885
#
# Loss 2.4845Loss 2.4845
#
# Loss 2.4890Loss 2.4890
#
# Loss 2.4901Loss 2.4901
#
# Loss 2.4841Loss 2.4841
#
# Loss 2.4837Loss 2.4837
#
# Loss 2.4873Loss 2.4873
#
# Loss 2.4856Loss 2.4856
#
# Loss 2.4869Loss 2.4869
#
# Loss 2.4813Loss 2.4813
#
# Loss 2.4843Loss 2.4843
#
# Loss 2.4794Loss 2.4794
#
# Loss 2.4838Loss 2.4838
#
# Loss 2.4853Loss 2.4853
#
# Loss 2.4787Loss 2.4787
#
# Loss 2.4835Loss 2.4835
#
# Loss 2.4803Loss 2.4803
#
# Loss 2.4798Loss 2.4798
#
# Loss 2.4784Loss 2.4784
#
# Loss 2.4812Loss 2.4812
#
# Loss 2.4830Loss 2.4830
#
# Loss 2.4861Loss 2.4861
#
# Loss 2.4788Loss 2.4788
#
# Loss 2.4798Loss 2.4798
#
# Loss 2.4791Loss 2.4791
#
# Loss 2.4755Loss 2.4755
#
# Loss 2.4751Loss 2.4751
#
# Loss 2.4745Loss 2.4745
#
# Loss 2.4672Loss 2.4672
#
# Loss 2.4780Loss 2.4780
#
# Loss 2.4737Loss 2.4737
#
# Loss 2.4739Loss 2.4739
#
# Loss 2.4760Loss 2.4760
#
# Loss 2.4699Loss 2.4699
#
# Loss 2.4816Loss 2.4816
#
# Loss 2.4737Loss 2.4737
#
# Loss 2.4709Loss 2.4709
#
# Loss 2.4716Loss 2.4716
#
# Loss 2.4717Loss 2.4717
#
# Loss 2.4685Loss 2.4685
#
# Loss 2.4684Loss 2.4684
#
# Loss 2.4751Loss 2.4751
#
# Loss 2.4718Loss 2.4718
#
# Loss 2.4738Loss 2.4738
#
# Loss 2.4733Loss 2.4733
#
# Loss 2.4645Loss 2.4645
#
# Loss 2.4640Loss 2.4640
#
# Loss 2.4581Loss 2.4581
#
# Loss 2.4619Loss 2.4619
#
# Loss 2.4682Loss 2.4682
#
# Loss 2.4709Loss 2.4709
#
# Loss 2.4640Loss 2.4640
#
# Loss 2.4618Loss 2.4618
#
# Loss 2.4649Loss 2.4649
#
# Loss 2.4616Loss 2.4616
#
# Loss 2.4669Loss 2.4669
#
# Loss 2.4633Loss 2.4633
#
# Loss 2.4661Loss 2.4661
#
# Loss 2.4621Loss 2.4621
#
# Loss 2.4633Loss 2.4633
#
# Loss 2.4691Loss 2.4691
#
# Loss 2.4570Loss 2.4570
#
# Loss 2.4566Loss 2.4566
#
# Loss 2.4563Loss 2.4563
#
# Loss 2.4584Loss 2.4584
#
# Loss 2.4537Loss 2.4537
#
# Loss 2.4659Loss 2.4659
#
# Loss 2.4505Loss 2.4505
#
# Loss 2.4600Loss 2.4600
#
# Loss 2.4529Loss 2.4529
#
# Loss 2.4596Loss 2.4596
#
# Loss 2.4568Loss 2.4568
#
# Loss 2.4592Loss 2.4592
#
# Loss 2.4565Loss 2.4565
#
# Loss 2.4515Loss 2.4515
#
# Loss 2.4549Loss 2.4549
#
# Loss 2.4513Loss 2.4513
#
# Loss 2.4503Loss 2.4503
#
# Loss 2.4571Loss 2.4571
#
# Loss 2.4543Loss 2.4543
#
# Loss 2.4487Loss 2.4487
#
# Loss 2.4462Loss 2.4462
#
# Loss 2.4524Loss 2.4524
#
# Loss 2.4575Loss 2.4575
#
# Loss 2.4465Loss 2.4465
#
# Loss 2.4494Loss 2.4494
#
# Loss 2.4412Loss 2.4412
#
# Loss 2.4546Loss 2.4546
#
# Loss 2.4543Loss 2.4543
#
# Loss 2.4427Loss 2.4427
#
# Loss 2.4507Loss 2.4507
#
# Loss 2.4467Loss 2.4467
#
# Loss 2.4424Loss 2.4424
#
# Loss 2.4462Loss 2.4462
#
# Loss 2.4409Loss 2.4409
#
# Loss 2.4422Loss 2.4422
#
# Loss 2.4422Loss 2.4422
#
# Loss 2.4400Loss 2.4400
#
# Loss 2.4461Loss 2.4461
#
# Loss 2.4417Loss 2.4417
#
# Loss 2.4378Loss 2.4378
#
# Loss 2.4523Loss 2.4523
#
# Loss 2.4446Loss 2.4446
#
# Loss 2.4450Loss 2.4450
#
# Loss 2.4441Loss 2.4441
#
# Loss 2.4347Loss 2.4347
#
# Loss 2.4387Loss 2.4387
#
# Loss 2.4361Loss 2.4361
#
# Loss 2.4403Loss 2.4403
#
# Loss 2.4422Loss 2.4422
#
# Loss 2.4294Loss 2.4294
#
# Loss 2.4294Loss 2.4294
#
# Loss 2.4358Loss 2.4358
#
# Loss 2.4395Loss 2.4395
#
# Loss 2.4292Loss 2.4292
#
# Loss 2.4386Loss 2.4386
#
# Loss 2.4387Loss 2.4387
#
# Loss 2.4330Loss 2.4330
#
# Loss 2.4301Loss 2.4301
#
# Loss 2.4258Loss 2.4258
#
# Loss 2.4328Loss 2.4328
#
# Loss 2.4314Loss 2.4314
#
# Loss 2.4325Loss 2.4325
#
# Loss 2.4237Loss 2.4237
#
# Loss 2.4299Loss 2.4299
#
# Loss 2.4329Loss 2.4329
#
# Loss 2.4283Loss 2.4283
#
# Loss 2.4362Loss 2.4362
#
# Loss 2.4303Loss 2.4303
#
# Loss 2.4327Loss 2.4327
#
# Loss 2.4260Loss 2.4260
#
# Loss 2.4210Loss 2.4210
#
# Loss 2.4325Loss 2.4325
#
# Loss 2.4303Loss 2.4303
#
# Loss 2.4334Loss 2.4334
#
# Loss 2.4290Loss 2.4290
#
# Loss 2.4245Loss 2.4245
#
# Loss 2.4226Loss 2.4226
#
# Loss 2.4200Loss 2.4200
#
# Loss 2.4238Loss 2.4238
#
# Loss 2.4247Loss 2.4247
#
# Loss 2.4298Loss 2.4298
#
# Loss 2.4201Loss 2.4201
#
# Loss 2.4233Loss 2.4233
#
# Loss 2.4171Loss 2.4171
#
# Loss 2.4178Loss 2.4178
#
# Loss 2.4283Loss 2.4283
#
# Loss 2.4083Loss 2.4083
#
# Loss 2.4356Loss 2.4356
#
# Loss 2.4156Loss 2.4156
#
# Loss 2.4121Loss 2.4121
#
# Loss 2.4287Loss 2.4287
#
# Loss 2.4109Loss 2.4109
#
# Loss 2.4202Loss 2.4202
#
# Loss 2.4193Loss 2.4193
#
# Loss 2.4193Loss 2.4193
#
# Loss 2.4172Loss 2.4172
#
# Loss 2.4164Loss 2.4164
#
# Loss 2.4132Loss 2.4132
#
# Loss 2.4158Loss 2.4158
#
# Loss 2.4158Loss 2.4158
#
# Loss 2.4068Loss 2.4068
#
# Loss 2.4155Loss 2.4155
#
# Loss 2.4067Loss 2.4067
#
# Loss 2.4143Loss 2.4143
#
# Loss 2.4070Loss 2.4070
#
# Loss 2.4143Loss 2.4143
#
# Loss 2.4045Loss 2.4045
#
# Loss 2.4101Loss 2.4101
#
# Loss 2.4013Loss 2.4013
#
# Loss 2.4149Loss 2.4149
#
# Loss 2.4028Loss 2.4028
#
# Loss 2.4104Loss 2.4104
#
# Loss 2.4046Loss 2.4046
#
# Loss 2.4108Loss 2.4108
#
# Loss 2.4080Loss 2.4080
#
# Loss 2.4040Loss 2.4040
#
# Loss 2.3997Loss 2.3997
#
# Loss 2.4098Loss 2.4098
#
# Loss 2.3984Loss 2.3984
#
# Loss 2.4008Loss 2.4008
#
# Loss 2.4080Loss 2.4080
#
# Loss 2.4029Loss 2.4029
#
# Loss 2.3998Loss 2.3998
#
# Loss 2.4005Loss 2.4005
#
# Loss 2.4103Loss 2.4103
#
# Loss 2.3994Loss 2.3994
#
# Loss 2.3978Loss 2.3978
#
# Loss 2.3983Loss 2.3983
#
# Loss 2.4012Loss 2.4012
#
# Loss 2.3927Loss 2.3927
#
# Loss 2.3965Loss 2.3965
#
# Loss 2.3959Loss 2.3959
#
# Loss 2.4030Loss 2.4030
#
# Loss 2.4060Loss 2.4060
#
# Loss 2.4018Loss 2.4018
#
# Loss 2.3896Loss 2.3896
#
# Loss 2.3999Loss 2.3999
#
# Loss 2.3912Loss 2.3912
#
# Loss 2.3947Loss 2.3947
#
# Loss 2.3940Loss 2.3940
#
# Loss 2.3990Loss 2.3990
#
# Loss 2.3982Loss 2.3982
#
# Loss 2.3892Loss 2.3892
#
# Loss 2.3898Loss 2.3898
#
# Loss 2.3999Loss 2.3999
#
# Loss 2.3919Loss 2.3919
#
# Loss 2.3873Loss 2.3873
#
# Loss 2.3942Loss 2.3942
#
# Loss 2.3992Loss 2.3992
#
# Loss 2.4038Loss 2.4038
#
# Loss 2.3913Loss 2.3913
#
# Loss 2.3874Loss 2.3874
#
# Loss 2.3932Loss 2.3932
#
# Loss 2.3826Loss 2.3826
#
# Loss 2.3977Loss 2.3977
#
# Loss 2.3857Loss 2.3857
#
# Loss 2.3953Loss 2.3953
#
# Loss 2.3838Loss 2.3838
#
# Loss 2.3912Loss 2.3912
#
# Loss 2.3794Loss 2.3794
#
# Loss 2.3843Loss 2.3843
#
# Loss 2.3779Loss 2.3779
#
# Loss 2.3923Loss 2.3923
#
# Loss 2.3854Loss 2.3854
#
# Loss 2.3871Loss 2.3871
#
# Loss 2.3808Loss 2.3808
#
# Loss 2.3765Loss 2.3765
#
# Loss 2.3779Loss 2.3779
#
# Loss 2.3715Loss 2.3715
#
# Loss 2.3742Loss 2.3742
#
# Loss 2.3808Loss 2.3808
#
# Loss 2.3727Loss 2.3727
#
# Loss 2.3754Loss 2.3754
#
# Loss 2.3834Loss 2.3834
#
# Loss 2.3704Loss 2.3704
#
# Loss 2.3813Loss 2.3813
#
# Loss 2.3765Loss 2.3765
#
# Loss 2.3777Loss 2.3777
#
# Loss 2.3832Loss 2.3832
#
# Loss 2.3818Loss 2.3818
#
# Loss 2.3752Loss 2.3752
#
# Loss 2.3712Loss 2.3712
#
# Loss 2.3730Loss 2.3730
#
# Loss 2.3714Loss 2.3714
#
# Loss 2.3811Loss 2.3811
#
# Loss 2.3733Loss 2.3733
#
# Loss 2.3740Loss 2.3740
#
# Loss 2.3723Loss 2.3723
#
# Loss 2.3795Loss 2.3795
#
# Loss 2.3682Loss 2.3682
#
# Loss 2.3704Loss 2.3704
#
# Loss 2.3609Loss 2.3609
#
# Loss 2.3726Loss 2.3726
#
# Loss 2.3606Loss 2.3606
#
# Loss 2.3679Loss 2.3679
#
# Loss 2.3610Loss 2.3610
#
# Loss 2.3654Loss 2.3654
#
# Loss 2.3783Loss 2.3783
#
# Loss 2.3774Loss 2.3774
#
# Loss 2.3620Loss 2.3620
#
# Loss 2.3707Loss 2.3707
#
# Loss 2.3619Loss 2.3619
#
# Loss 2.3659Loss 2.3659
#
# Loss 2.3658Loss 2.3658
#
# Loss 2.3652Loss 2.3652
#
# Loss 2.3572Loss 2.3572
#
# Loss 2.3682Loss 2.3682
#
# Loss 2.3589Loss 2.3589
#
# Loss 2.3551Loss 2.3551
#
# Loss 2.3522Loss 2.3522
#
# Loss 2.3494Loss 2.3494
#
# Loss 2.3586Loss 2.3586
#
# Loss 2.3545Loss 2.3545
#
# Loss 2.3744Loss 2.3744
#
# Loss 2.3560Loss 2.3560
#
# Loss 2.3658Loss 2.3658
#
# Loss 2.3734Loss 2.3734
#
# Loss 2.3591Loss 2.3591
#
# Loss 2.3504Loss 2.3504
#
# Loss 2.3634Loss 2.3634
#
# Loss 2.3550Loss 2.3550
#
# Loss 2.3589Loss 2.3589
#
# Loss 2.3524Loss 2.3524
#
# Loss 2.3570Loss 2.3570
#
# Loss 2.3493Loss 2.3493
#
# Loss 2.3545Loss 2.3545
#
# Loss 2.3540Loss 2.3540
#
# Loss 2.3495Loss 2.3495
#
# Loss 2.3568Loss 2.3568
#
# Loss 2.3603Loss 2.3603
#
# Loss 2.3609Loss 2.3609
#
# Loss 2.3544Loss 2.3544
#
# Loss 2.3589Loss 2.3589
#
# Loss 2.3715Loss 2.3715
#
# Loss 2.3561Loss 2.3561
#
# Loss 2.3466Loss 2.3466
#
# Loss 2.3438Loss 2.3438
#
# Loss 2.3537Loss 2.3537
#
# Loss 2.3448Loss 2.3448
#
# Loss 2.3511Loss 2.3511
#
# Loss 2.3480Loss 2.3480
#
# Loss 2.3563Loss 2.3563
#
# Loss 2.3670Loss 2.3670
#
# Loss 2.3380Loss 2.3380
#
# Loss 2.3563Loss 2.3563
#
# Loss 2.3444Loss 2.3444
#
# Loss 2.3347Loss 2.3347
#
# Loss 2.3513Loss 2.3513
#
# Loss 2.3422Loss 2.3422
#
# Loss 2.3422Loss 2.3422
#
# Loss 2.3415Loss 2.3415
#
# Loss 2.3355Loss 2.3355
#
# Loss 2.3368Loss 2.3368
#
# Loss 2.3530Loss 2.3530
#
# Loss 2.3355Loss 2.3355
#
# Loss 2.3449Loss 2.3449
#
# Loss 2.3403Loss 2.3403
#
# Loss 2.3334Loss 2.3334
#
# Loss 2.3351Loss 2.3351
#
# Loss 2.3385Loss 2.3385
#
# Loss 2.3264Loss 2.3264
#
# Loss 2.3223Loss 2.3223
#
# Loss 2.3435Loss 2.3435
#
# Loss 2.3359Loss 2.3359
#
# Loss 2.3331Loss 2.3331
#
# Loss 2.3351Loss 2.3351
#
# Loss 2.3289Loss 2.3289
#
# Loss 2.3404Loss 2.3404
#
# Loss 2.3441Loss 2.3441
#
# Loss 2.3415Loss 2.3415
#
# Loss 2.3213Loss 2.3213
#
# Loss 2.3366Loss 2.3366
#
# Loss 2.3280Loss 2.3280
#
# Loss 2.3386Loss 2.3386
#
# Loss 2.3399Loss 2.3399
#
# Loss 2.3219Loss 2.3219
#
# Loss 2.3288Loss 2.3288
#
# Loss 2.3233Loss 2.3233
#
# Loss 2.3335Loss 2.3335
#
# Loss 2.3217Loss 2.3217
#
# Loss 2.3202Loss 2.3202
#
# Loss 2.3356Loss 2.3356
#
# Loss 2.3264Loss 2.3264
#
# Loss 2.3282Loss 2.3282
#
# Loss 2.3394Loss 2.3394
#
# Loss 2.3331Loss 2.3331
#
# Loss 2.3302Loss 2.3302
#
# Loss 2.3295Loss 2.3295
#
# Loss 2.3267Loss 2.3267
#
# Loss 2.3396Loss 2.3396
#
# Loss 2.3123Loss 2.3123
#
# Loss 2.3281Loss 2.3281
#
# Loss 2.3262Loss 2.3262
#
# Loss 2.3126Loss 2.3126
#
# Loss 2.3102Loss 2.3102
#
# Loss 2.3294Loss 2.3294
#
# Loss 2.3225Loss 2.3225
#
# Loss 2.3180Loss 2.3180
#
# Loss 2.3327Loss 2.3327
#
# Loss 2.3206Loss 2.3206
#
# Loss 2.3127Loss 2.3127
#
# Loss 2.3104Loss 2.3104
#
# Loss 2.3162Loss 2.3162
#
# Loss 2.3303Loss 2.3303
#
# Loss 2.3297Loss 2.3297
#
# Loss 2.3183Loss 2.3183
#
# Loss 2.3158Loss 2.3158
#
# Loss 2.3159Loss 2.3159
#
# Loss 2.3095Loss 2.3095
#
# Loss 2.3264Loss 2.3264
#
# Loss 2.3099Loss 2.3099
#
# Loss 2.3183Loss 2.3183
#
# Loss 2.3199Loss 2.3199
#
# Loss 2.3222Loss 2.3222
#
# Loss 2.3083Loss 2.3083
#
# Loss 2.3087Loss 2.3087
#
# Loss 2.3067Loss 2.3067
#
# Loss 2.3281Loss 2.3281
#
# Loss 2.3017Loss 2.3017
#
# Loss 2.3151Loss 2.3151
#
# Loss 2.3055Loss 2.3055
#
# Loss 2.3091Loss 2.3091
#
# Loss 2.3082Loss 2.3082
#
# Loss 2.3174Loss 2.3174
#
# Loss 2.2990Loss 2.2990
#
# Loss 2.3143Loss 2.3143
#
# Loss 2.3121Loss 2.3121
#
# Loss 2.3165Loss 2.3165
#
# Loss 2.2983Loss 2.2983
#
# Loss 2.2968Loss 2.2968
#
# Loss 2.3148Loss 2.3148
#
# Loss 2.3042Loss 2.3042
#
# Loss 2.2938Loss 2.2938
#
# Loss 2.3069Loss 2.3069
#
# Loss 2.2939Loss 2.2939
#
# Loss 2.3170Loss 2.3170
#
# Loss 2.3163Loss 2.3163
#
# Loss 2.2952Loss 2.2952
#
# Loss 2.2951Loss 2.2951
#
# Loss 2.2939Loss 2.2939
#
# Loss 2.3204Loss 2.3204
#
# Loss 2.2908Loss 2.2908
#
# Loss 2.2841Loss 2.2841
#
# Loss 2.3045Loss 2.3045
#
# Loss 2.3036Loss 2.3036
#
# Loss 2.2898Loss 2.2898
#
# Loss 2.2896Loss 2.2896
#
# Loss 2.3064Loss 2.3064
#
# Loss 2.3071Loss 2.3071
#
# Loss 2.2889Loss 2.2889
#
# Loss 2.2990Loss 2.2990
#
# Loss 2.2986Loss 2.2986
#
# Loss 2.2854Loss 2.2854
#
# Loss 2.3018Loss 2.3018
#
# Loss 2.2882Loss 2.2882
#
# Loss 2.2938Loss 2.2938
#
# Loss 2.2774Loss 2.2774
#
# Loss 2.2937Loss 2.2937
#
# Loss 2.2784Loss 2.2784
#
# Loss 2.3032Loss 2.3032
#
# Loss 2.2962Loss 2.2962
#
# Loss 2.2866Loss 2.2866
#
# Loss 2.2934Loss 2.2934
#
# Loss 2.2879Loss 2.2879
#
# Loss 2.2991Loss 2.2991
#
# Loss 2.2898Loss 2.2898
#
# Loss 2.2786Loss 2.2786
#
# Loss 2.2941Loss 2.2941
#
# Loss 2.2870Loss 2.2870
#
# Loss 2.2993Loss 2.2993
#
# Loss 2.2912Loss 2.2912
#
# Loss 2.2800Loss 2.2800
#
# Loss 2.2931Loss 2.2931
#
# Loss 2.2756Loss 2.2756
#
# Loss 2.2854Loss 2.2854
#
# Loss 2.2820Loss 2.2820
#
# Loss 2.2876Loss 2.2876
#
# Loss 2.2819Loss 2.2819
#
# Loss 2.2866Loss 2.2866
#
# Loss 2.2703Loss 2.2703
#
# Loss 2.2800Loss 2.2800
#
# Loss 2.2875Loss 2.2875
#
# Loss 2.2799Loss 2.2799
#
# Loss 2.2791Loss 2.2791
#
# Loss 2.2753Loss 2.2753
#
# Loss 2.2796Loss 2.2796
#
# Loss 2.2764Loss 2.2764
#
# Loss 2.2782Loss 2.2782
#
# Epoch 1 completed: Loss 2.2782 Accuracy 90.62Epoch 1 completed: Loss 2.2782 Accuracy 90.62
#
#
# Execution Time Summary:
# Execution Time Summary:
#
# Total time for generate_random_ring_element: 518.9893 secondsTotal time for generate_random_ring_element: 525.5414 seconds
#
# Total time for generate_additive_triple: 242.4077 secondsTotal time for generate_additive_triple: 242.0394 seconds
#
# Total time for generate_kbit_random_tensor: 359.8003 secondsTotal time for generate_kbit_random_tensor: 360.5292 seconds
#
# Total time for generate_binary_triple: 359.0411 secondsTotal time for generate_binary_triple: 364.2708 seconds
#
# Total time for B2A_rng: 38.0321 secondsTotal time for B2A_rng: 38.5741 seconds
#
# Total time for square: 73.1326 secondsTotal time for square: 73.4865 seconds
#
#
# Total execution time: 1591.4031 seconds
# Total execution time: 1604.4414 seconds

# %%
import torch
import crypten

crypten.init() 

label = torch.Tensor([1, 2, 3, 4])
print(label)
# 输出: tensor([1., 2., 3., 4.])
label = crypten.cryptensor(label)
filled_tensor = crypten.cryptensor(torch.full(label.size(), 0))
crypten.print(f"filled_tensor_dec:{filled_tensor.get_plain_text()}")
# Out:
# tensor([1., 2., 3., 4.])
# filled_tensor_dec:tensor([0., 0., 0., 0.])
# /home/sue/Project/PR-crypten/CrypTen/crypten/__init__.py:64: RuntimeWarning: CrypTen is already initialized.
#   warnings.warn("CrypTen is already initialized.", RuntimeWarning)
